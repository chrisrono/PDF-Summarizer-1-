# %%
import os

# %%
os.listdir()
# Out:
# ['+123-456-7890 (1).png',
#  '+123-456-7890 (10).png',
#  '+123-456-7890 (11).png',
#  '+123-456-7890 (2).png',
#  '+123-456-7890 (3).png',
#  '+123-456-7890 (4).png',
#  '+123-456-7890 (5).png',
#  '+123-456-7890 (6).png',
#  '+123-456-7890 (7).png',
#  '+123-456-7890 (8).png',
#  '+123-456-7890 (9).png',
#  '+123-456-7890.png',
#  '+123-456-7890.zip',
#  '.179b76cfe2760f6b25b280f7d7a9040324460d6c.parts',
#  '.ipynb_checkpoints',
#  '1. Digitalisation in finance.docx',
#  '19a01280760d407f969f700071116c22.HD-1080p-7.2Mbps-16362511.mp4',
#  '1x',
#  '2nd Class.pdf',
#  '3. Fintech Regulations in Africa.docx',
#  'A Corporate Ambient.mp3',
#  'A Corporate Ambient1.mp3',
#  'A lost century in economics_ Three theories of banking and the conclusive evidence.pdf',
#  'A016947037H.pdf',
#  'Adobe Premiere Pro Audio Previews',
#  'Adobe Premiere Pro Auto-Save',
#  'Advertisement - Vacant Positions in the Public Service September 2023.pdf',
#  'Aksarben Logo.png',
# ...

# %%
cwd = os.getcwd()
cwd
# Out:
# 'C:\\Users\\chris\\Downloads'

# %%
# !pip install langchain
# !pip install unstructured
# !pip install openai
# !pip install chromadb
# !pip install Cython
# !pip install tiktoken
# Out:
# ...
#   Obtaining dependency information for chromadb from https://files.pythonhosted.org/packages/7c/cc/8b822be150323492e1d3c2ae46ccd99ddc9841894afdc41c408ffd68918e/chromadb-0.4.22-py3-none-any.whl.metadata
#   Using cached chromadb-0.4.22-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Obtaining dependency information for build>=1.0.3 from https://files.pythonhosted.org/packages/93/dd/b464b728b866aaa62785a609e0dd8c72201d62c5f7c53e7c20f4dceb085f/build-1.0.3-py3-none-any.whl.metadata
#   Using cached build-1.0.3-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Obtaining dependency information for chroma-hnswlib==0.7.3 from https://files.pythonhosted.org/packages/d2/32/a91850c7aa8a34f61838913155103808fe90da6f1ea4302731b59e9ba6f2/chroma_hnswlib-0.7.3-cp311-cp311-win_amd64.whl.metadata
#   Using cached chroma_hnswlib-0.7.3-cp311-cp311-win_amd64.whl.metadata (262 bytes)
# ...

# %%
# !pip install transformers

# %%
# !pip install PyPDF2

# %%
import os
import openai
from transformers import pipeline
import PyPDF2

# Set your OpenAI API key
openai.api_key = "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"

# Load the summarization pipeline
summarizer = pipeline("summarization")

# Function to generate summary for a PDF
def generate_summary(pdf_path, chunk_size=1000, max_length=150, min_length=50):
    with open(pdf_path, 'rb') as file:
        pdf_text = ""
        pdf_reader = PyPDF2.PdfReader(file)
        for page in pdf_reader.pages:
            pdf_text += page.extract_text()

        # Split text into chunks
        chunks = [pdf_text[i:i + chunk_size] for i in range(0, len(pdf_text), chunk_size)]

        # Generate summaries for each chunk
        summaries = []
        for i, chunk in enumerate(chunks):
            summary = summarizer(chunk, max_length=max_length, min_length=min_length, do_sample=False)
            summaries.append(summary[0]['summary_text'])

        return "\n".join(summaries)

if __name__ == '__main__':
    pdf_dir = 'C:\Users\chris\Downloads\Compressed\MangrovePDFs'

    for filename in os.listdir(pdf_dir):
        if filename.lower().endswith('.pdf'):
            pdf_path = os.path.join(pdf_dir, filename)
            pdf_summary = generate_summary(pdf_path)

            print(f"PDF: {filename}\nSummary:\n{pdf_summary}\n{'=' * 30}")
